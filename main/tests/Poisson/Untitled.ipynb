# %%
jt -r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-46fef22f58e3> in <module>
# ----> 1 jt -r
#
# NameError: name 'jt' is not defined
